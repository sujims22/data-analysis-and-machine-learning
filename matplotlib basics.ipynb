# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
x=np.arange(1,9)
y=2*x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('name')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
x=np.array([1,3,5,6])
y=np.array([6,7,8,9])
z=3*x
plt.plot(x,y,'o',color='g',label='lineofcontrol')
plt.plot(x,z,label='likewise')
plt.grid(True)
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(y,x,'o')

# %%
plt.subplot(2,1,1)
plt.plot(x,y)

plt.subplot(2,1,2)
plt.plot(y,x,'o')

# %%
plt.subplot(3,1,1)
plt.plot(x,y)

plt.subplot(3,1,2)
plt.plot(y,x,'o')

plt.subplot(3,1,3)
plt.plot(x,y,color='g')

# %%
plt.plot(x,y,y,y)

# %%
f={'x':1,'y':2,'z':3}
a=list(f.keys())
b=list(f.values())
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(a, b)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.scatter(a,b,c='g')

# %%
plt.scatter(a,b,c='g',marker='*')

# %%
x1=np.arange(8)
y1=np.arange(1,16,2)
z1=3*y1+5
plt.scatter(x1,z1,marker='*',s=30,c='g')
plt.scatter(x1,y1)

# %%
x=range(10,19)
y=np.arange(9)
z=[3,6,7,8,0,2,3,4,5]
plt.subplot(1,2,1)
plt.scatter(x,z,c='g',s=20,marker='*')
plt.subplot(1,2,2)
plt.scatter(y,x,c='b')
plt.show()

# %%
l=[8,8,9,0,0,0,5,6,7]
plt.hist(l,color='r',bins=5,edgecolor='b')
# Out:
# (array([3., 0., 1., 2., 3.]),
#  array([0. , 1.8, 3.6, 5.4, 7.2, 9. ]),
#  <BarContainer object of 5 artists>)

# %%
l1=[3,3,4,7,9,0,2,3,4]
l2=[8,9,0]
l=list([l1,l2])
plt.boxplot(l)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28a284d9f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28a28600610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28a284d9bb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x28a28600cd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x28a2860d070>,
# ...
#  'means': []}

# %%
plt.violinplot(l)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x28a286686a0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x28a286684f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x28a28668580>,
#  'cbars': <matplotlib.collections.LineCollection at 0x28a286821f0>}

# %%
plt.violinplot(l,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x28a284c86a0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x28a284c88b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x28a2845d2e0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x28a284519a0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x28a28451970>}

# %%
y=np.array([4,6,7,8])
names=['life','love','laugh','peace']
plt.pie(y,labels=names)
plt.show()

# %%
y=np.array([4,6,7,8])
names=['life','love','laugh','peace']
plt.pie(y,labels=names,startangle=180)
plt.show()
# Out:
# No handles with labels found to put in legend.
