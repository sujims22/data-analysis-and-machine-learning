# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sb.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.displot(df['tip'])

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='sex')

# %%
sns.rugplot(df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.barplot(x='sex',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x='tip',data=df,hue='smoker')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,hue='smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='size',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.boxplot(x='size',y='tip',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.stripplot(x='size',y='tip',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.stripplot(x='size',y='tip',data=df,hue='sex',jitter=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.set_context('paper')
sns.set_style('white')
plt.subplot(2,2,1)
sns.scatterplot(x='size',y='tip',data=df,hue='sex')
plt.subplot(2,2,2)
sns.swarmplot(x='size',y='tip',data=df,hue='sex')
plt.subplot(2,2,3)
sns.violinplot(x='size',y='tip',data=df,hue='sex')
plt.figure(figsize=(1,10))
sns.set_palette('cool')
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 27.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='sex',y='tip',data=df,hue='size')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x='size',y='tip',data=df,hue='sex')
sns.swarmplot(x='size',y='tip',data=df,hue='sex',color='black')
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip',data=df)
sns.swarmplot(x='day',y='tip',data=df,color='white')
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=df)
sns.set_style('whitegrid')
sns.set_context('talk')
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=df,hue='sex')

sns.set_context('talk')
plt.figure(figsize=(1,8))
sns.set_palette('plasma')
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=df,hue='sex')
sns.set_style('white')
sns.set_palette('Spectral')
plt.legend(loc=2)
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
t=df.corr()
sns.heatmap(t,annot=True,cmap='cool')
# Out:
# <AxesSubplot:>

# %%
c=pd.pivot_table(df,index='size',columns='sex')
c
sns.heatmap(c)
# Out:
# <AxesSubplot:xlabel='None-sex', ylabel='size'>

# %%
df2=sns.load_dataset('flights')
t=pd.pivot_table(df2,index='year',values='passengers',columns='month')
sns.heatmap(t,linecolor='white',linewidth=2)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.clustermap(t)

# %%
dfiris=sns.load_dataset('iris')

dfiris.pop('species')

sns.heatmap(dfiris,annot=True)
# Out:
# <AxesSubplot:>

# %%
plot=sns.PairGrid(df,hue='sex')

plot.map_diag(sns.kdeplot)
plot.map_upper(sns.barplot)
plot.map_lower(plt.scatter)

# %%
graph = sns.FacetGrid(df, col ="sex",  hue ="day")

graph.map(plt.scatter, "total_bill", "tip", edgecolor ="w").add_legend()

# %%
graph = sns.FacetGrid(df, col ="day",  hue ="sex")
graph.map(sns.distplot,'tip')
graph.add_legend()
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
graph = sns.FacetGrid(df, col ="day",  hue ="sex")
graph.map(sns.barplot,'size','tip')
graph.add_legend()
# Out:
# C:\Users\Sujitha\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.lmplot(data=df,x='total_bill',y='tip',hue='sex',row='size',col='day')
